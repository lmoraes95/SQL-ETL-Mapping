# %%
import pandas as pd
from sqlalchemy import create_engine
from pathlib import Path

# %%
#import data
imdb_data = "../Resources/IMDB_data.csv"
imdb_df = pd.read_csv(imdb_data)
imdb_df.head()
# Out:
#                                          Poster_Link      Series_Title  \
# 0  https://m.media-amazon.com/images/M/MV5BYTRiND...   Game of Thrones
# 1  https://m.media-amazon.com/images/M/MV5BMjhiMz...      Breaking Bad
# 2  https://m.media-amazon.com/images/M/MV5BMTc5Zm...  The Walking Dead
# 3  https://m.media-amazon.com/images/M/MV5BNDVkYj...           Friends
# 4  https://m.media-amazon.com/images/M/MV5BMjEzMD...   Stranger Things
#
#   Runtime_of_Series Certificate Runtime_of_Episodes                     Genre  \
# 0       (2011–2019)           A              57 min  Action, Adventure, Drama
# 1       (2008–2013)          18              49 min    Crime, Drama, Thriller
# 2          (2010– )         18+              44 min   Drama, Horror, Thriller
# 3       (1994–2004)         13+              22 min           Comedy, Romance
# 4          (2016– )          15              51 min    Drama, Fantasy, Horror
#
#    IMDB_Rating                                           Overview  \
# ...

# %%
#find which columns have null values
imdb_df.loc[:, imdb_df.isnull().any()].columns
# Out:
# Index(['Certificate', 'Runtime_of_Episodes', 'Star3', 'Star4'], dtype='object')

# %%
#drop tables that we don't need or that have null values
imdb_df.drop(['Certificate', 'Poster_Link', 'Overview', 'Star1', 'Star2', 'Runtime_of_Episodes', 'Star3', 'Star4'], axis = 1, inplace = True)
imdb_df.head()
# Out:
#        Series_Title Runtime_of_Series                     Genre  IMDB_Rating  \
# 0   Game of Thrones       (2011–2019)  Action, Adventure, Drama          9.3
# 1      Breaking Bad       (2008–2013)    Crime, Drama, Thriller          9.5
# 2  The Walking Dead          (2010– )   Drama, Horror, Thriller          8.2
# 3           Friends       (1994–2004)           Comedy, Romance          8.9
# 4   Stranger Things          (2016– )    Drama, Fantasy, Horror          8.7
#
#    No_of_Votes
# 0      1773458
# 1      1468887
# 2       854698
# 3       829816
# 4       824966

# %%
#import data
netflix_data = "../Resources/Netflix_data.csv"
netflix_df = pd.read_csv(netflix_data)
netflix_df.head()
# Out:
#    Unnamed: 0 show_id     type                  title         director  \
# 0           1      s2  TV Show          Blood & Water              NaN
# 1           2      s3  TV Show              Ganglands  Julien Leclercq
# 2           3      s4  TV Show  Jailbirds New Orleans              NaN
# 3           4      s5  TV Show           Kota Factory              NaN
# 4           5      s6  TV Show          Midnight Mass    Mike Flanagan
#
#                                                 cast       country  \
# 0  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...  South Africa
# 1  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...           NaN
# 2                                                NaN           NaN
# 3  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...         India
# 4  Kate Siegel, Zach Gilford, Hamish Linklater, H...           NaN
#
#    date_added  release_year rating  duration  \
# 0  2021-09-24          2021  TV-MA         0
# ...

# %%
#find columns with null values
netflix_df.loc[:, netflix_df.isnull().any()].columns
# Out:
# Index(['director', 'cast', 'country', 'date_added', 'rating', 'year_added',
#        'month_added'],
#       dtype='object')

# %%
netflix_df.drop(['director', 'cast', 'country', 'date_added', 'rating', 'year_added', 'month_added', 'show_id', 'duration', 'listed_in', 'description'], axis = 1, inplace = True)
netflix_df.head()
# Out:
#    Unnamed: 0     type                  title  release_year  season_count
# 0           1  TV Show          Blood & Water          2021             2
# 1           2  TV Show              Ganglands          2021             1
# 2           3  TV Show  Jailbirds New Orleans          2021             1
# 3           4  TV Show           Kota Factory          2021             2
# 4           5  TV Show          Midnight Mass          2021             1

# %%
#drop unnamed columns
netflix_df.drop(netflix_df.columns[0], axis=1, inplace=True)
netflix_df.head()
# Out:
#       type                  title  release_year  season_count
# 0  TV Show          Blood & Water          2021             2
# 1  TV Show              Ganglands          2021             1
# 2  TV Show  Jailbirds New Orleans          2021             1
# 3  TV Show           Kota Factory          2021             2
# 4  TV Show          Midnight Mass          2021             1

# %%
netflix_df.index.name = 'index'
imdb_df.index.name = 'index'

# %%
netflix_df.head()
# Out:
#           type                  title  release_year  season_count
# index
# 0      TV Show          Blood & Water          2021             2
# 1      TV Show              Ganglands          2021             1
# 2      TV Show  Jailbirds New Orleans          2021             1
# 3      TV Show           Kota Factory          2021             2
# 4      TV Show          Midnight Mass          2021             1

# %%
imdb_df.head()
# Out:
#            Series_Title Runtime_of_Series                     Genre  \
# index
# 0       Game of Thrones       (2011–2019)  Action, Adventure, Drama
# 1          Breaking Bad       (2008–2013)    Crime, Drama, Thriller
# 2      The Walking Dead          (2010– )   Drama, Horror, Thriller
# 3               Friends       (1994–2004)           Comedy, Romance
# 4       Stranger Things          (2016– )    Drama, Fantasy, Horror
#
#        IMDB_Rating  No_of_Votes
# index
# 0              9.3      1773458
# 1              9.5      1468887
# 2              8.2       854698
# 3              8.9       829816
# 4              8.7       824966

# %%
#creating a clean csv file
imdb_df.head()
filepath = Path("../Resources/IMDB_data_clean.csv")
filepath.parent.mkdir(parents=True, exist_ok=True) 
imdb_df.to_csv(filepath)

netflix_df.head()
filepath = Path("../Resources/Netflix_data_clean.csv")
filepath.parent.mkdir(parents=True, exist_ok=True) 
netflix_df.to_csv(filepath)

# %%
imdb_df["Series_Title"].value_counts()
# Out:
# The Twilight Zone               4
# Whose Line Is It Anyway?        3
# Teenage Mutant Ninja Turtles    3
# Knight Rider                    2
# Twin Peaks                      2
#                                ..
# Man vs. Wild                    1
# Zoo                             1
# United States of Tara           1
# The Missing                     1
# Comic Book Men                  1
# Name: Series_Title, Length: 1956, dtype: int64

# %%
max = imdb_df.sort_values(by='IMDB_Rating', ascending=False)
max.head()
# Out:
#                              Series_Title Runtime_of_Series  \
# index
# 1003                           The Chosen          (2017– )
# 483                 The Filthy Frank Show       (2011–2017)
# 1                            Breaking Bad       (2008–2013)
# 844                              Koombiyo       (2017–2018)
# 182    Scam 1992: The Harshad Mehta Story            (2020)
#
#                          Genre  IMDB_Rating  No_of_Votes
# index
# 1003            Drama, History          9.7        13085
# 483     Comedy, Fantasy, Music          9.5        32155
# 1       Crime, Drama, Thriller          9.5      1468887
# 844     Crime, Drama, Thriller          9.5        16391
# 182    Biography, Crime, Drama          9.4        86565

# %%
imdb_df_dup_drop = max.drop_duplicates(subset=['Series_Title'], keep='first')

# %%
imdb_df_dup_drop["Series_Title"].value_counts()
# Out:
# The Chosen                            1
# Law & Order: Criminal Intent          1
# Dark Angel                            1
# Two Guys, a Girl and a Pizza Place    1
# Empire                                1
#                                      ..
# Boy Meets World                       1
# Dead Like Me                          1
# Criminal Minds                        1
# Voltron: Legendary Defender           1
# Iste Bu Benim Masalim                 1
# Name: Series_Title, Length: 1956, dtype: int64

# %%
#creating a clean csv file
imdb_df_dup_drop.head()
filepath = Path("../Resources/imbd.csv")
filepath.parent.mkdir(parents=True, exist_ok=True) 
imdb_df_dup_drop.to_csv(filepath)

netflix_df.head()
filepath = Path("../Resources/netflix.csv")
filepath.parent.mkdir(parents=True, exist_ok=True) 
netflix_df.to_csv(filepath)
